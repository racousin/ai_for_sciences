# %% [markdown]
# # TP2: Text Representation and Tokenization
#
# **Day 1 - AI for Sciences Winter School**
#
# **Instructor:** Raphael Cousin
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/raphaelcousin/ai_for_sciences/blob/main/day1/tp2.ipynb)
#
# ## Topics
# - Text representation
# - Understanding tokenizers
# - Byte-pair encoding (BPE)
