# %% [markdown]
# # TP3: GPT Architecture and Fine-Tuning
#
# **Day 1 - AI for Sciences Winter School**
#
# **Instructor:** Raphael Cousin
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/raphaelcousin/ai_for_sciences/blob/main/day1/tp3.ipynb)
#
# ## Topics
# - GPT architecture
# - One-shot learning with Hugging Face
# - Fine-tuning techniques
